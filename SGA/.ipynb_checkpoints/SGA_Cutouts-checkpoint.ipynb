# %%
import os
import numpy as np
import fitsio
from astropy.io import fits
from astropy.table import Table
from tqdm import tqdm
import math
import pandas as pd

# %% [markdown]
# # Format SGA 2020 Data

# %%
sga2020 = Table.read('/global/cfs/cdirs/cosmo/data/sga/2020/SGA-2020.fits', hdu=1)
sga2020_RA_DEC = Table()
sga2020_RA_DEC['TargetID'] = sga2020['SGA_ID']
sga2020_RA_DEC['Target_RA'] = sga2020['RA']
sga2020_RA_DEC['Target_DEC'] = sga2020['DEC']
df2020 = sga2020_RA_DEC.to_pandas()
#df2020[6821:6825].to_csv("/pscratch/sd/q/qshimp/SGA2020-data/sga2020_RA_DEC_testDaniel.csv")
df2020
# Out:
#         TargetID   Target_RA  Target_DEC
# 0              2  228.377080    5.423191
# 1              3  202.544462    6.934624
# 2              4  222.749705   13.861930
# 3              7  182.088822   25.602268
# 4             18  188.533649   45.595620
# ...          ...         ...         ...
# 383615   5005230   77.397506  -27.106360
# 383616   5005238  354.025414   24.266269
# 383617   5005241  359.778506   23.672056
# 383618   5005244  193.433619   24.573018
# 383619   5005247  220.726633   19.287173
#
# [383620 rows x 3 columns]

# %%
# Check for duplicate Target IDs
duplicates = df2020[df2020.duplicated(subset='TargetID', keep=False)]
print(f"{len(duplicates)} duplicate IDs")
# Out:
# 0 duplicate IDs

# %%
# Identifying irrelevant coordinate differentiation
def MergeNearCoords(df):
    for decimals in range(10, 0, -1):
        copy = df.copy()
    
        copy['RA_round'] = copy['Target_RA'].round(decimals)
        copy['DEC_round'] = copy['Target_DEC'].round(decimals)
    
        duplicates = copy[copy.duplicated(subset=['RA_round', 'DEC_round'], keep=False)]
    
        if len(duplicates) > 0: # ALL USELESS, MAKE SIMPLE
            print(f"Coordinate dilution occurs at {decimals} decimals")
            df['RA_round'] = df['Target_RA'].round(3)
            df['DEC_round'] = df['Target_DEC'].round(3)
            break
    # Remove irrelevant coordinates
    duplicates = df[df.duplicated(subset=['RA_round', 'DEC_round'], keep="last")]
    uniqueObjects = df.drop(duplicates.index)
    uniqueObjects = uniqueObjects.drop(columns=['RA_round', 'DEC_round'])
    return uniqueObjects
    
uniqueObjects2020 = MergeNearCoords(df2020)
uniqueObjects2020
df2020
# Out:
# Coordinate dilution occurs at 3 decimals
#         TargetID   Target_RA  Target_DEC  RA_round  DEC_round
# 0              2  228.377080    5.423191   228.377      5.423
# 1              3  202.544462    6.934624   202.544      6.935
# 2              4  222.749705   13.861930   222.750     13.862
# 3              7  182.088822   25.602268   182.089     25.602
# 4             18  188.533649   45.595620   188.534     45.596
# ...          ...         ...         ...       ...        ...
# 383615   5005230   77.397506  -27.106360    77.398    -27.106
# 383616   5005238  354.025414   24.266269   354.025     24.266
# 383617   5005241  359.778506   23.672056   359.779     23.672
# 383618   5005244  193.433619   24.573018   193.434     24.573
# 383619   5005247  220.726633   19.287173   220.727     19.287
#
# [383620 rows x 5 columns]

# %% [markdown]
# # Format SGA 2025 Data

# %%
sgaBeta2025 = Table.read('/global/cfs/cdirs/cosmo/work/legacysurvey/sga/2025/SGA2025-beta-parent-refcat-v1.6.kd.fits', hdu = 1)
df2025 = sgaBeta2025.to_pandas()
df2025.rename(columns={"ra": "Target_RA", "dec": "Target_DEC", "ref_id": "TargetID"}, inplace=True)
df2025
# Out:
#          Target_RA  Target_DEC  TargetID        mag  fitmode          pa  \
# 0       219.925802  -32.530045   4176048  17.780001        0   70.355278
# 1       219.891999  -32.342994   4176016  17.709999        0  150.428970
# 2       219.940904  -32.331298    242036  17.840000        0  134.882629
# 3       220.209215  -32.010931    243654  18.040001        0   91.798492
# 4       220.362323  -31.994911   4257822  15.400000        0   10.682078
# ...            ...         ...       ...        ...      ...         ...
# 470620   30.146677   28.225196   5005050  12.831638        0  162.803253
# 470621   30.867045   28.274770   4957379  16.096416        0   84.813797
# 470622   30.360603   28.734268   4807432  14.230906        0   54.906796
# 470623   30.320490   28.836853   5054143  11.612162        0    1.327161
# 470624   30.188173   28.873484   4678425  16.593575        0  137.503754
#
#               ba       diam
# 0       0.583230   0.555508
# 1       0.460713   0.507900
# 2       0.220731   0.682237
# 3       0.703881   0.507167
# 4       0.616908   1.066838
# ...          ...        ...
# 470620  0.342439   3.757807
# 470621  0.607179   0.527874
# 470622  0.786671   0.765473
# 470623  0.183276  10.501398
# 470624  0.388474   0.498173
#
# [470625 rows x 8 columns]

# %%
# Check for duplicate Ref IDs
duplicates = df2025[df2025.duplicated(subset='TargetID', keep=False)]
print(f"{len(duplicates)} duplicate IDs")
# Out:
# 0 duplicate IDs

# %%
uniqueObjects2025 = MergeNearCoords(df2025)
uniqueObjects2025
# All objects are unique
# Out:
# Coordinate dilution occurs at 2 decimals
#          Target_RA  Target_DEC  TargetID        mag  fitmode          pa  \
# 0       219.925802  -32.530045   4176048  17.780001        0   70.355278
# 1       219.891999  -32.342994   4176016  17.709999        0  150.428970
# 2       219.940904  -32.331298    242036  17.840000        0  134.882629
# 3       220.209215  -32.010931    243654  18.040001        0   91.798492
# 4       220.362323  -31.994911   4257822  15.400000        0   10.682078
# ...            ...         ...       ...        ...      ...         ...
# 470620   30.146677   28.225196   5005050  12.831638        0  162.803253
# 470621   30.867045   28.274770   4957379  16.096416        0   84.813797
# 470622   30.360603   28.734268   4807432  14.230906        0   54.906796
# 470623   30.320490   28.836853   5054143  11.612162        0    1.327161
# 470624   30.188173   28.873484   4678425  16.593575        0  137.503754
#
#               ba       diam
# 0       0.583230   0.555508
# 1       0.460713   0.507900
# 2       0.220731   0.682237
# 3       0.703881   0.507167
# 4       0.616908   1.066838
# ...          ...        ...
# 470620  0.342439   3.757807
# 470621  0.607179   0.527874
# 470622  0.786671   0.765473
# 470623  0.183276  10.501398
# 470624  0.388474   0.498173
#
# [470625 rows x 8 columns]

# %% [markdown]
# # Identify 2020 galxies within SGA 2025

# %%
# Function that adds a column that identifies data from one SGA set (giveID) in another set (receiveID)
def CompareDataset(df_receiveID, df_giveID):
    coords = ["RA_round", "DEC_round"]
    
    give_subset = df_giveID[coords + ["TargetID"]].copy()
    give_subset = give_subset.rename(columns={"TargetID": "SGA ID"})
    give_subset = give_subset.drop_duplicates(subset=coords) # In case I change my formatting code later
    
    merged_df = pd.merge(df_receiveID, give_subset, on=coords, how='left')
    merged_df["SGA ID"] = merged_df["SGA ID"].astype("Int64")
    return merged_df
    
df2025Compared = CompareDataset(df2025, df2020)
df2025Compared
# Out:
#          Target_RA  Target_DEC  TargetID        mag  fitmode          pa  \
# 0       219.925802  -32.530045   4176048  17.780001        0   70.355278
# 1       219.891999  -32.342994   4176016  17.709999        0  150.428970
# 2       219.940904  -32.331298    242036  17.840000        0  134.882629
# 3       220.209215  -32.010931    243654  18.040001        0   91.798492
# 4       220.362323  -31.994911   4257822  15.400000        0   10.682078
# ...            ...         ...       ...        ...      ...         ...
# 470620   30.146677   28.225196   5005050  12.831638        0  162.803253
# 470621   30.867045   28.274770   4957379  16.096416        0   84.813797
# 470622   30.360603   28.734268   4807432  14.230906        0   54.906796
# 470623   30.320490   28.836853   5054143  11.612162        0    1.327161
# 470624   30.188173   28.873484   4678425  16.593575        0  137.503754
#
#               ba       diam  RA_round  DEC_round   SGA ID
# 0       0.583230   0.555508   219.926    -32.530     <NA>
# 1       0.460713   0.507900   219.892    -32.343     <NA>
# 2       0.220731   0.682237   219.941    -32.331     <NA>
# 3       0.703881   0.507167   220.209    -32.011     <NA>
# 4       0.616908   1.066838   220.362    -31.995     <NA>
# ...          ...        ...       ...        ...      ...
# 470620  0.342439   3.757807    30.147     28.225  1250853
# 470621  0.607179   0.527874    30.867     28.275  1070616
# 470622  0.786671   0.765473    30.361     28.734   502445
# 470623  0.183276  10.501398    30.320     28.837     <NA>
# 470624  0.388474   0.498173    30.188     28.873    13764
#
# [470625 rows x 11 columns]

# %%
df2025Cleaned = df2025Compared[df2025Compared['SGA ID'].isna()]
df2025Cleaned = df2025Cleaned.drop(columns=["SGA ID", "RA_round", "DEC_round"])
df2025Cleaned
# Out:
#          Target_RA  Target_DEC  TargetID        mag  fitmode          pa  \
# 0       219.925802  -32.530045   4176048  17.780001        0   70.355278
# 1       219.891999  -32.342994   4176016  17.709999        0  150.428970
# 2       219.940904  -32.331298    242036  17.840000        0  134.882629
# 3       220.209215  -32.010931    243654  18.040001        0   91.798492
# 4       220.362323  -31.994911   4257822  15.400000        0   10.682078
# ...            ...         ...       ...        ...      ...         ...
# 470599   29.748286   27.061345   3345171  13.347000        0   59.265774
# 470603   31.308315   27.139710   3888284  18.170000        0   85.974800
# 470608   31.454218   27.408196   3168451  16.190001        0  108.342827
# 470611   30.775969   27.506619   1333435  19.167000        0  100.055969
# 470623   30.320490   28.836853   5054143  11.612162        0    1.327161
#
#               ba       diam
# 0       0.583230   0.555508
# 1       0.460713   0.507900
# 2       0.220731   0.682237
# 3       0.703881   0.507167
# 4       0.616908   1.066838
# ...          ...        ...
# 470599  0.714058   0.530304
# 470603  0.698627   0.416352
# 470608  0.860133   0.892261
# 470611  0.822534   0.456332
# 470623  0.183276  10.501398
#
# [194284 rows x 8 columns]

# %%
PIX_SCALE       = 0.262       # arcsec/pixel for Legacy Surveys
CUTOUT_SIZE_PIX = 152         # fixed 152x152 cutouts
scale = 1 # Manually adjust this to change allowed galaxy size
diamMax = scale*PIX_SCALE*CUTOUT_SIZE_PIX/60 # max diameter in arcmin
print(f"Cutout length/height: {diamMax} arcmin")

sizedTargets = df2025[df2025['diam'] <= diamMax]
print(f"{len(sizedTargets)} targets in sample")
bigs = df2025[df2025['diam'] > diamMax]
print(f"{len(bigs)} oversized galaxies removed")
# Out:
# Cutout length/height: 0.6637333333333333 arcmin
# 216313 targets in sample
# 254312 oversized galaxies removed

# %% [markdown]
# ##### Interesting note
# I mistakenly used 39.824 arcmin instead of arsec; this pulled 8 largest objects (still sorted by ID.
# First 3 have no galaxy, fourth and fifth are Magellanic Clouds, sixth is Sculptor Galaxy,
# seventh is a faint, large cloud of stars, eighth is Triangulum Galaxy

# %%
# Create table of 2025 SGA data
#sizedTargets[:3].to_csv("/pscratch/sd/q/qshimp/SGA2025-data/sga2025_sizedTargets.csv")
sizedTargets
# Out:
#          Target_RA  Target_DEC  TargetID        mag  fitmode          pa  \
# 0       219.925802  -32.530045   4176048  17.780001        0   70.355278
# 1       219.891999  -32.342994   4176016  17.709999        0  150.428970
# 3       220.209215  -32.010931    243654  18.040001        0   91.798492
# 5       219.972199  -31.718623   4180680  17.139999        0   92.536026
# 6       219.529606  -31.677126    245155  18.219999        0   60.774433
# ...            ...         ...       ...        ...      ...         ...
# 470616   30.209306   27.704670   5043592  16.017002        0  170.846390
# 470617   30.309906   27.843988   5025683  15.463606        0   49.214359
# 470619   30.226417   27.951572   4736513  15.985822        0   92.121376
# 470621   30.867045   28.274770   4957379  16.096416        0   84.813797
# 470624   30.188173   28.873484   4678425  16.593575        0  137.503754
#
#               ba      diam  RA_round  DEC_round
# 0       0.583230  0.555508   219.926    -32.530
# 1       0.460713  0.507900   219.892    -32.343
# 3       0.703881  0.507167   220.209    -32.011
# 5       0.544621  0.561025   219.972    -31.719
# 6       0.209309  0.588386   219.530    -31.677
# ...          ...       ...       ...        ...
# 470616  0.562225  0.578457    30.209     27.705
# 470617  0.665927  0.545319    30.310     27.844
# 470619  0.791888  0.638258    30.226     27.952
# 470621  0.607179  0.527874    30.867     28.275
# 470624  0.388474  0.498173    30.188     28.873
#
# [216313 rows x 10 columns]

# %% [markdown]
# ##### Copy this code to run fp_cutouts in galaxy morphology directory
# python FP_cutouts.py --csv /pscratch/sd/q/qshimp/SGA2020-data/sga2020_RA_DEC_testDaniel.csv --outdir /pscratch/sd/q/qshimp/Cutouts/sga2020
#
# Replace --csv file path with file path generated up above, replace --outdir file path with folder to store cutouts
