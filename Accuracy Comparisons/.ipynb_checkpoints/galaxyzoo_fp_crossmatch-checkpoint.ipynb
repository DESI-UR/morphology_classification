# %%
import pandas as pd
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from collections import defaultdict
from astropy.coordinates import SkyCoord
import astropy.units as u
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    classification_report, accuracy_score
)

# %%
# Loading Data
galaxyzoo = Table.read("/pscratch/sd/j/jlargett/DESI_SGA_MINE/Sorter/gz_desi_deep_learning_catalog_friendly.csv")
galaxyzoo
# Out:
# <Table length=8689370>
#    dr8_id       ra       dec     ... catalog_version legacy_survey_data_release
#    str12     float64   float64   ...       str5                 str3
# ----------- --------- ---------- ... --------------- --------------------------
# 100000_1081 32.084931 -44.311422 ...           1.0.0                        DR8
# 100000_1401 32.140085 -44.293668 ...           1.0.0                        DR8
# 100000_1483 32.275015 -44.288957 ...           1.0.0                        DR8
# 100000_1509 32.045648 -44.287172 ...           1.0.0                        DR8
# 100000_1869 32.170627 -44.267273 ...           1.0.0                        DR8
# 100000_1901 32.264953 -44.264718 ...           1.0.0                        DR8
# 100000_2004 32.104085 -44.257405 ...           1.0.0                        DR8
# 100000_2198 32.097469 -44.250979 ...           1.0.0                        DR8
# 100000_2211 32.149425 -44.242194 ...           1.0.0                        DR8
# ...

# %%
# Load FP catalog
FP = Table.read('/pscratch/sd/j/jlargett/DESI_SGA_MINE/Sorter/FP/FP_Targets_SSL.csv')
FP
# Out:
# <Table length=160444>
#       targetid      ...
#        int64        ...
# ------------------- ...
#    2398569927540753 ...
#    2411764067074053 ...
#    2411812238655501 ...
#    2411853036650517 ...
#    2802785447837696 ...
#    2802841915752448 ...
#    2802929287299072 ...
#    2802962501992448 ...
#    2803015878705152 ...
#    2803286583279616 ...
#                 ... ...
# 2305843047834848439 ...
# 2305843047843237422 ...
# 2305843047843242097 ...
# 2305843047847429986 ...
# 2305843047851626571 ...
# 2305843047855821074 ...
# 2305843047860016411 ...
# 2305843056437369156 ...
# 2305843056441572262 ...
# 2305843056445751758 ...

# %%
# Create SkyCoord objects
galzoo_coords = SkyCoord(ra=galaxyzoo["ra"] * u.deg,
                     dec=galaxyzoo["dec"] * u.deg)

fp_coords = SkyCoord(ra=FP["ra"] * u.deg,
                      dec=FP["dec"] * u.deg)

# Do a cone search (cross-match) within 1 arcseconds
idx_fp, idx_galzoo, sep2d, _ = galzoo_coords.search_around_sky(fp_coords, 1 * u.arcsec)

# This gives you the indices of matches from both catalogs
print(f"Number of matched targets: {len(idx_fp)}")
print(f"Number of matched targets: {len(idx_galzoo)}")
# Out:
# Number of matched targets: 154969
# Number of matched targets: 154969

# %%
# --- Build candidate-pair table (still one row per candidate match) ---
matches = Table()

# FP fields
matches["fp_targetid"] = FP["targetid"][idx_fp]
matches["fp_ra"]       = FP["ra"][idx_fp]
matches["fp_dec"]      = FP["dec"][idx_fp]

# Galaxy Zoo fields
matches["dr8_id"] = galaxyzoo["dr8_id"][idx_galzoo]
matches["gz_ra"]  = galaxyzoo["ra"][idx_galzoo]
matches["gz_dec"] = galaxyzoo["dec"][idx_galzoo]

# Add Galaxy Zoo vote fractions (needed for morphology classification)
vote_columns = [
    "has-spiral-arms_yes_fraction",
    "smooth-or-featured_smooth_fraction",
    "smooth-or-featured_featured-or-disk_fraction",
    "smooth-or-featured_artifact_fraction",
    "merging_major-disturbance_fraction",
    "merging_minor-disturbance_fraction",
    "merging_merger_fraction",
]
for col in vote_columns:
    matches[col] = galaxyzoo[col][idx_galzoo]

# Separation
matches["sep_arcsec"] = sep2d.arcsec

# --- Greedy one-to-one selection (smallest separation wins; no repeats on either side) ---
order = np.argsort(matches["sep_arcsec"])

used_fp = set()
used_gz = set()
keep = []

for i in order:
    fp_id = matches["fp_targetid"][i]
    gz_id = matches["dr8_id"][i]
    if (fp_id not in used_fp) and (gz_id not in used_gz):
        keep.append(i)
        used_fp.add(fp_id)
        used_gz.add(gz_id)

matches_1to1 = matches[keep]
matches_1to1.sort("sep_arcsec")

matches_1to1
# Out:
# <Table length=130170>
#     fp_targetid           fp_ra        ...       sep_arcsec
#        int64             float64       ...        float64
# ------------------- ------------------ ... ----------------------
#   39627532290492361  358.0726659999005 ... 2.0644099146914896e-06
#    2842376347320329  204.7980510005146 ...  6.200949008550869e-06
#   39627775207802521 152.58498600083666 ...  6.284195180989364e-06
#   39628332018434898 1.6823129977178477 ...   8.88881072889495e-06
# 2305843018621522677 225.53148399797067 ...  1.324784280523956e-05
#   39633365887880634 250.73685199339164 ... 1.4175083066145288e-05
#   39628072458126268  337.6073220024723 ...  1.480153473025379e-05
#   39633461048250261 256.09521899910106 ... 1.6307694543765215e-05
#   39627756660592734  127.1786749966846 ...  1.655934921258623e-05
#   39633351874708882 132.29273599171367 ... 1.6982208017695826e-05
#                 ...                ... ...                    ...
# ...

# %%
print("FP duplicates:", len(matches_1to1) != len(np.unique(matches_1to1["fp_targetid"])))
print("GZ duplicates:", len(matches_1to1) != len(np.unique(matches_1to1["dr8_id"])))
# Out:
# FP duplicates: False
# GZ duplicates: False

# %%
# Very basic classification scheme
def classify_morphology(row):
    # Key vote fractions
    spiral = row.get('has-spiral-arms_yes_fraction', 0)
    smooth = row.get('smooth-or-featured_smooth_fraction', 0)
    featured = row.get('smooth-or-featured_featured-or-disk_fraction', 0)
    artifact = row.get('smooth-or-featured_artifact_fraction', 0)

    disturbed = row.get('merging_major-disturbance_fraction', 0) + \
                row.get('merging_minor-disturbance_fraction', 0) + \
                row.get('merging_merger_fraction', 0)

    # Classification Rules based on DESI GZ decision tree
    # 1. Artifact or strongly disturbed → Irregular
    if artifact > 0.3 or disturbed > 0.3:
        return 'Irregular'

    # 2. Clear spiral arms → Spiral
    if spiral > 0.5:
        return 'Spiral'

    # 3. Smooth galaxy (no features) → Elliptical
    if smooth > 0.5:
        return 'Elliptical'

    # 4. Disk-like, no arms, not smooth → Lenticular
    if spiral < 0.3 and smooth < 0.5 and featured > 0.3:
        return 'Lenticular'

    # 5. unclassifiable
    return 'Unclassified'

# %%
# Apply classification row-by-row
morph_classes = [
    classify_morphology(dict(row))
    for row in matches_1to1
]

# Add as a new column
matches_1to1["morphology"] = morph_classes

# %%
types, counts = np.unique(matches_1to1["morphology"], return_counts=True)

for t, c in zip(types, counts):
    print(f"{t}: {c}")
# Out:
# Elliptical: 96951
# Irregular: 22031
# Lenticular: 454
# Spiral: 3215
# Unclassified: 7519

# %%
mask = matches_1to1["morphology"] != "Unclassified"
matches_clean = matches_1to1[mask]

matches_clean
# Out:
# <Table length=122651>
#     fp_targetid           fp_ra        ...       sep_arcsec       morphology
#        int64             float64       ...        float64           str12
# ------------------- ------------------ ... ---------------------- ----------
#   39627532290492361  358.0726659999005 ... 2.0644099146914896e-06  Irregular
#    2842376347320329  204.7980510005146 ...  6.200949008550869e-06  Irregular
#   39627775207802521 152.58498600083666 ...  6.284195180989364e-06 Elliptical
#   39628332018434898 1.6823129977178477 ...   8.88881072889495e-06 Elliptical
# 2305843018621522677 225.53148399797067 ...  1.324784280523956e-05 Elliptical
#   39633365887880634 250.73685199339164 ... 1.4175083066145288e-05 Elliptical
#   39628072458126268  337.6073220024723 ...  1.480153473025379e-05 Elliptical
#   39633461048250261 256.09521899910106 ... 1.6307694543765215e-05 Elliptical
#   39627756660592734  127.1786749966846 ...  1.655934921258623e-05 Elliptical
# ...

# %%
np.unique(matches_clean["morphology"], return_counts=True)
# Out:
# (<Column name='morphology' dtype='str12' length=4>
#  Elliptical
#   Irregular
#  Lenticular
#      Spiral,
#  array([96951, 22031,   454,  3215]))

# %%
matches_clean.write('/pscratch/sd/j/jlargett/DESI_SGA_MINE/Sorter/FP/Generating_Anchor_Points/gz_fp_comparison.csv', format="csv", overwrite=True)
